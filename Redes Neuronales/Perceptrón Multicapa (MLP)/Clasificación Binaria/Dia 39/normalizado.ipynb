# %%
import seaborn as sns
import scipy.stats as stats
import random

# %%
# Generar datos exponenciales
df2 = [random.expovariate(0.2) for _ in range(1000)]
df2 = np.array(df2).reshape(-1, 1)  # Convertir la lista en un array de NumPy

# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
import joblib
import tensorflow as tf

# %%
import pylab
import scipy.stats as stats

# %%
w,p = stats.shapiro(df2)
print(w,p)
# Out:
# 0.8437660905557052 3.025277889990115e-30

# %%
sns.histplot(df2,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
from sklearn.preprocessing import PowerTransformer

# %%
# Aplicar transformación Yeo-Johnson
pt = PowerTransformer(method='yeo-johnson')
df2_normalizado = pt.fit_transform(df2)

# %%
w,p = stats.shapiro(df2_normalizado)
print(w,p)
# Out:
# 0.9847952336689906 1.081957282529119e-08

# %%
sns.histplot(df2_normalizado)
# Out:
# <Axes: ylabel='Count'>

# %%
plt.figure(df2)
stats.probplot(df2,dist='norm',plot=pylab)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[180], line 1
# ----> 1 plt.figure(df2)
#       2 stats.probplot(df2,dist='norm',plot=pylab)
#
# File c:\Users\Frank\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:1011, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#    1009         num = allnums[inum]
#    1010 else:
# -> 1011     num = int(num)  # crude validation of num argument
#    1013 # Type of "num" has narrowed to int, but mypy can't quite see it
#    1014 manager = _pylab_helpers.Gcf.get_fig_manager(num)  # type: ignore[arg-type]
#
# TypeError: only length-1 arrays can be converted to Python scalars
