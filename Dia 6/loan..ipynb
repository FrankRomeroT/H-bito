# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
def custom_warning_format(message, category, filename, lineno, file=None, line=None):
    return f'{filename}:{lineno}: {category.__name__}: {message}\n'

# %%
df = pd.read_csv('C:/Users/FRANK/Desktop/Proyectos Linkedin/Python Proyectos/Dia 6/LoanDataset - LoansDatasest.csv')
df.head()
# Out:
#    customer_id  customer_age customer_income home_ownership  \
# 0          1.0            22           59000           RENT
# 1          2.0            21            9600            OWN
# 2          3.0            25            9600       MORTGAGE
# 3          4.0            23           65500           RENT
# 4          5.0            24           54400           RENT
#
#    employment_duration loan_intent loan_grade   loan_amnt  loan_int_rate  \
# 0                123.0    PERSONAL          C  £35,000.00          16.02
# 1                  5.0   EDUCATION          A   £1,000.00          11.14
# 2                  1.0     MEDICAL          B   £5,500.00          12.87
# 3                  4.0     MEDICAL          B  £35,000.00          15.23
# 4                  8.0     MEDICAL          B  £35,000.00          14.27
#
#    term_years historical_default  cred_hist_length Current_loan_status
# 0          10                  Y                 3             DEFAULT
# 1           1                NaN                 2          NO DEFAULT
# 2           5                  N                 3             DEFAULT
# 3          10                  N                 2             DEFAULT
# 4          10                  Y                 4             DEFAULT

# %%
df2 = df.copy()
print('Número de observaciones (filas) = {}'.format(df2.shape[0]))
print('Total de variables disponibles = {} '.format(df2.columns.shape[0]))
print('Columnas que cuentan con un valor nulo-')
print(df2.isnull().sum())
# Out:
# Número de observaciones (filas) = 32586
# Total de variables disponibles = 13
# Columnas que cuentan con un valor nulo-
# customer_id                3
# customer_age               0
# customer_income            0
# home_ownership             0
# employment_duration      895
# loan_intent                0
# loan_grade                 0
# loan_amnt                  1
# loan_int_rate           3116
# term_years                 0
# historical_default     20737
# cred_hist_length           0
# Current_loan_status        4
# dtype: int64

# %%
df2['loan_amnt'] = df2['loan_amnt'].replace('[\£,]','',regex=True)
df2['loan_amnt'] = df2['loan_amnt'].astype(float)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32586 entries, 0 to 32585
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          32583 non-null  float64
#  1   customer_age         32586 non-null  int64
#  2   customer_income      32586 non-null  object
#  3   home_ownership       32586 non-null  object
#  4   employment_duration  31691 non-null  float64
#  5   loan_intent          32586 non-null  object
#  6   loan_grade           32586 non-null  object
#  7   loan_amnt            32585 non-null  float64
#  8   loan_int_rate        29470 non-null  float64
#  9   term_years           32586 non-null  int64
#  10  historical_default   11849 non-null  object
#  11  cred_hist_length     32586 non-null  int64
#  12  Current_loan_status  32582 non-null  object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 3.2+ MB

# %%
df2.head()
# Out:
#    customer_id  customer_age customer_income home_ownership  \
# 0          1.0            22           59000           RENT
# 1          2.0            21            9600            OWN
# 2          3.0            25            9600       MORTGAGE
# 3          4.0            23           65500           RENT
# 4          5.0            24           54400           RENT
#
#    employment_duration loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0                123.0    PERSONAL          C    35000.0          16.02
# 1                  5.0   EDUCATION          A     1000.0          11.14
# 2                  1.0     MEDICAL          B     5500.0          12.87
# 3                  4.0     MEDICAL          B    35000.0          15.23
# 4                  8.0     MEDICAL          B    35000.0          14.27
#
#    term_years historical_default  cred_hist_length Current_loan_status
# 0          10                  Y                 3             DEFAULT
# 1           1                NaN                 2          NO DEFAULT
# 2           5                  N                 3             DEFAULT
# 3          10                  N                 2             DEFAULT
# 4          10                  Y                 4             DEFAULT

# %%
print(df2[df2['customer_id'].isnull()])
# Out:
#        customer_id  customer_age customer_income home_ownership  \
# 25559          NaN            31           83000           RENT
# 25560          NaN            30           86000       MORTGAGE
# 25561          NaN            27           74000       MORTGAGE
#
#        employment_duration        loan_intent loan_grade  loan_amnt  \
# 25559                  2.0           PERSONAL          B    12000.0
# 25560                  7.0  DEBTCONSOLIDATION          B    10000.0
# 25561                  3.0           PERSONAL          B    25000.0
#
#        loan_int_rate  term_years historical_default  cred_hist_length  \
# 25559          12.42           1                NaN                 7
# 25560            NaN           3                NaN                10
# 25561          11.46           7                  N                 5
#
#       Current_loan_status
# 25559          NO DEFAULT
# 25560          NO DEFAULT
# 25561             DEFAULT

# %%
df2 = df2.sort_values(by='customer_id').reset_index(drop=True) # ordenar el dataframe
df2['customer_id'] = range(1,len(df2)+1)
print("Verificar duplicados:")
print(df2['customer_id'].duplicated().any())
# Out:
# Verificar duplicados:
# False

# %%
interpolate_column = ['customer_id','customer_age','customer_income','employment_duration','loan_int_rate','term_years','loan_amnt']
df2[interpolate_column] = df2[interpolate_column].interpolate(method='linear')
# Out:
# C:\Users\FRANK\AppData\Local\Temp\ipykernel_13316\2628607070.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df2[interpolate_column] = df2[interpolate_column].interpolate(method='linear')

# %%
print('Columnas que cuentan con un valor nulo-')
print(df2.isnull().sum())
# Out:
# Columnas que cuentan con un valor nulo-
# customer_id                0
# customer_age               0
# customer_income            0
# home_ownership             0
# employment_duration        0
# loan_intent                0
# loan_grade                 0
# loan_amnt                  0
# loan_int_rate              0
# term_years                 0
# historical_default     20737
# cred_hist_length           0
# Current_loan_status        4
# dtype: int64

# %%
df2.head()
# Out:
#    customer_id  customer_age customer_income home_ownership  \
# 0            1            22           59000           RENT
# 1            2            21            9600            OWN
# 2            3            25            9600       MORTGAGE
# 3            4            23           65500           RENT
# 4            5            24           54400           RENT
#
#    employment_duration loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0                123.0    PERSONAL          C    35000.0          16.02
# 1                  5.0   EDUCATION          A     1000.0          11.14
# 2                  1.0     MEDICAL          B     5500.0          12.87
# 3                  4.0     MEDICAL          B    35000.0          15.23
# 4                  8.0     MEDICAL          B    35000.0          14.27
#
#    term_years historical_default  cred_hist_length Current_loan_status
# 0          10                  Y                 3             DEFAULT
# 1           1                NaN                 2          NO DEFAULT
# 2           5                  N                 3             DEFAULT
# 3          10                  N                 2             DEFAULT
# 4          10                  Y                 4             DEFAULT

# %%
print(df2['Current_loan_status'].value_counts())
print('-'*50)
print(df2['historical_default'].value_counts())
# Out:
# Current_loan_status
# NO DEFAULT    25742
# DEFAULT        6840
# Name: count, dtype: int64
# --------------------------------------------------
# historical_default
# Y    6128
# N    5721
# Name: count, dtype: int64

# %%
def convert_status(value, type):
    if type == 'Current_loan_status':
        if value == 'NO DEFAULT':
            return 0
        elif value == 'DEFAULT':
            return 1
        else:
            return None  # Manejo de valores inesperados
    elif type == 'historical_default':
        if value == 'Y':
            return 1
        elif value == 'N':
            return 0
        else:
            return None  # Manejo de valores inesperados
    return value
      
# Aplicar las conversiones
df2['Current_loan_status'] = df2['Current_loan_status'].apply(lambda x: convert_status(x,'Current_loan_status'))
df2['historical_default'] = df2['historical_default'].apply(lambda x: convert_status(x,'historical_default'))

# %%
print(df2['Current_loan_status'].value_counts())
print(df2['historical_default'].value_counts())
# Out:
# Current_loan_status
# 0.0    25742
# 1.0     6840
# Name: count, dtype: int64
# historical_default
# 1.0    6128
# 0.0    5721
# Name: count, dtype: int64

# %%
df2.head()
# Out:
#    customer_id  customer_age customer_income home_ownership  \
# 0            1            22           59000           RENT
# 1            2            21            9600            OWN
# 2            3            25            9600       MORTGAGE
# 3            4            23           65500           RENT
# 4            5            24           54400           RENT
#
#    employment_duration loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0                123.0    PERSONAL          C    35000.0          16.02
# 1                  5.0   EDUCATION          A     1000.0          11.14
# 2                  1.0     MEDICAL          B     5500.0          12.87
# 3                  4.0     MEDICAL          B    35000.0          15.23
# 4                  8.0     MEDICAL          B    35000.0          14.27
#
#    term_years  historical_default  cred_hist_length  Current_loan_status
# 0          10                 1.0                 3                  1.0
# 1           1                 NaN                 2                  0.0
# 2           5                 0.0                 3                  1.0
# 3          10                 0.0                 2                  1.0
# 4          10                 1.0                 4                  1.0

# %%
df2.isnull().sum()
# Out:
# customer_id                0
# customer_age               0
# customer_income            0
# home_ownership             0
# employment_duration        0
# loan_intent                0
# loan_grade                 0
# loan_amnt                  0
# loan_int_rate              0
# term_years                 0
# historical_default     20737
# cred_hist_length           0
# Current_loan_status        4
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32586 entries, 0 to 32585
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          32586 non-null  int64
#  1   customer_age         32586 non-null  int64
#  2   customer_income      32586 non-null  object
#  3   home_ownership       32586 non-null  object
#  4   employment_duration  32586 non-null  float64
#  5   loan_intent          32586 non-null  object
#  6   loan_grade           32586 non-null  object
#  7   loan_amnt            32586 non-null  float64
#  8   loan_int_rate        32586 non-null  float64
#  9   term_years           32586 non-null  int64
#  10  historical_default   11849 non-null  float64
#  11  cred_hist_length     32586 non-null  int64
#  12  Current_loan_status  32582 non-null  float64
# dtypes: float64(5), int64(4), object(4)
# memory usage: 3.2+ MB

# %%
from sklearn.impute import KNNImputer

# Crear una instancia del KNNImputer
imputer = KNNImputer(n_neighbors=2)

# Imputar los valores nulos
df2[['historical_default',
      'customer_age',
      'customer_income',
       'term_years',
       'cred_hist_length',
       'Current_loan_status']] = imputer.fit_transform(df2[['historical_default',
                                                            'customer_age',
                                                            'customer_income',
                                                            'term_years',
                                                            'cred_hist_length',
                                                            'Current_loan_status']])

 # Asegurarse de que los valores imputados son enteros (0 o 1)
df2['historical_default'] = df2['historical_default'].round().astype(int)
df2['Current_loan_status'] = df2['Current_loan_status'].round().astype(int)
print(df2['Current_loan_status'].value_counts())
print(df2['historical_default'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13316\2152600629.py in ?()
#       8       'customer_age',
#       9       'customer_income',
#      10        'term_years',
#      11        'cred_hist_length',
# ---> 12        'Current_loan_status']] = imputer.fit_transform(df2[['historical_default',
#      13                                                             'customer_age',
#      14                                                             'customer_income',
#      15                                                             'term_years',
#
# c:\Users\FRANK\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     271     @wraps(f)
#     272     def wrapped(self, X, *args, **kwargs):
# --> 273         data_to_wrap = f(self, X, *args, **kwargs)
#     274         if isinstance(data_to_wrap, tuple):
#     275             # only wrap the first output for cross decomposition
#     276             return_tuple = (
#
# c:\Users\FRANK\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1057                 )
#    1058
#    1059         if y is None:
#    1060             # fit method of arity 1 (unsupervised transformation)
# -> 1061             return self.fit(X, **fit_params).transform(X)
#    1062         else:
#    1063             # fit method of arity 2 (supervised transformation)
#    1064             return self.fit(X, y, **fit_params).transform(X)
#
# c:\Users\FRANK\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1347                 skip_parameter_validation=(
#    1348                     prefer_skip_nested_validation or global_skip_validation
#    1349                 )
#    1350             ):
# -> 1351                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\FRANK\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\impute\_knn.py in ?(self, X, y)
#     226             force_all_finite = True
#     227         else:
#     228             force_all_finite = "allow-nan"
#     229
# --> 230         X = self._validate_data(
#     231             X,
#     232             accept_sparse=False,
#     233             dtype=FLOAT_DTYPES,
#
# c:\Users\FRANK\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# c:\Users\FRANK\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     948                         )
#     949                     array = xp.astype(array, dtype, copy=False)
#     950                 else:
#     951                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 952             except ComplexWarning as complex_warning:
#     953                 raise ValueError(
#     954                     "Complex data not supported\n{}\n".format(array)
#     955                 ) from complex_warning
#
# c:\Users\FRANK\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     517         # Use NumPy API to support order
#     518         if copy is True:
#     519             array = numpy.array(array, order=order, dtype=dtype)
#     520         else:
# --> 521             array = numpy.asarray(array, order=order, dtype=dtype)
#     522
#     523         # At this point array is a NumPy ndarray. We convert it to an array
#     524         # container that is consistent with the input's namespace.
#
# c:\Users\FRANK\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: '250,000'

# %%
df2.isnull().sum()
# Out:
# customer_id            0
# customer_age           0
# customer_income        0
# home_ownership         0
# employment_duration    0
# loan_intent            0
# loan_grade             0
# loan_amnt              0
# loan_int_rate          0
# term_years             0
# historical_default     0
# cred_hist_length       0
# Current_loan_status    4
# dtype: int64
