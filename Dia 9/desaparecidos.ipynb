# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
def custom_warning_format(message, category, filename, lineno, file=None, line=None):
    return f'{filename}:{lineno}: {category.__name__}: {message}\n'

# %%
df = pd.read_csv('C:/Users/FRANK/Desktop/Proyectos Linkedin/Python Proyectos/Dia 9/MM_14_21.csv')
df.head()
# Out:
#    Unnamed: 0        Main ID    Incident ID         Region  \
# 0           0  2014.MMP00001  2014.MMP00001  North America
# 1           1  2014.MMP00002  2014.MMP00002  North America
# 2           2  2014.MMP00003  2014.MMP00003  North America
# 3           3  2014.MMP00004  2014.MMP00004  North America
# 4           4  2014.MMP00005  2014.MMP00005         Europe
#
#              Incident Date  Year Reported Month  Number Dead  \
# 0  Mon, 01/06/2014 - 12:00  2014        January          1.0
# 1  Sun, 01/12/2014 - 12:00  2014        January          1.0
# 2  Tue, 01/14/2014 - 12:00  2014        January          1.0
# 3  Thu, 01/16/2014 - 12:00  2014        January          1.0
# 4  Thu, 01/16/2014 - 12:00  2014        January          1.0
#
#    Minimum Estimated Number of Missing  Total Number of Dead and Missing  ...  \
# 0                                  NaN                                 1  ...
# 1                                  NaN                                 1  ...
# 2                                  NaN                                 1  ...
# 3                                  NaN                                 1  ...
# 4                                  0.0                                 1  ...
#
#    Number of Males  Number of Children  \
# 0              1.0                 NaN
# 1              NaN                 NaN
# 2              NaN                 NaN
# 3              1.0                 NaN
# 4              1.0                 NaN
#
#                                       Cause of Death  \
# 0                                   Mixed or unknown
# 1                                   Mixed or unknown
# 2                                   Mixed or unknown
# 3                                           Violence
# 4  Harsh environmental conditions / lack of adequ...
#
#                                    Location of death  \
# 0  Pima Country Office of the Medical Examiner ju...
# 1  Pima Country Office of the Medical Examiner ju...
# 2  Pima Country Office of the Medical Examiner ju...
# 3                         near Douglas, Arizona, USA
# 4                  Border between Russia and Estonia
#
#                                   Information Source             Coordinates  \
# 0  Pima County Office of the Medical Examiner (PC...  31.650259, -110.366453
# 1  Pima County Office of the Medical Examiner (PC...    31.59713, -111.73756
# 2  Pima County Office of the Medical Examiner (PC...    31.94026, -113.01125
# 3  Ministry of Foreign Affairs Mexico, Pima Count...  31.506777, -109.315632
# 4                  EUBusiness (Agence France-Presse)             59.1551, 28
#
#             Migrantion route                         URL  \
# 0  US-Mexico border crossing  http://humaneborders.info/
# 1  US-Mexico border crossing                         NaN
# 2  US-Mexico border crossing                         NaN
# 3  US-Mexico border crossing       http://bit.ly/1qfIw00
# 4                        NaN       http://bit.ly/1rTFTjR
#
#   UNSD Geographical Grouping Source Quality
# 0           Northern America            5.0
# 1           Northern America            5.0
# 2           Northern America            5.0
# 3           Northern America            5.0
# 4            Northern Europe            1.0
#
# [5 rows x 22 columns]

# %%
df2 = df.copy()
print('Número de observaciones (filas) = {}'.format(df2.shape[0]))
print('Total de variables disponibles (columnas) = {} '.format(df2.columns.shape[0]))
print('Columnas que cuentan con un valor nulo -')
print(df2.isnull().sum())
# Out:
# Número de observaciones (filas) = 9906
# Total de variables disponibles (columnas) = 22
# Columnas que cuentan con un valor nulo -
# Unnamed: 0                                0
# Main ID                                   0
# Incident ID                               0
# Region                                    0
# Incident Date                            15
# Year                                      0
# Reported Month                            0
# Number Dead                             552
# Minimum Estimated Number of Missing    8871
# Total Number of Dead and Missing          0
# Number of Survivors                    8427
# Number of Females                      8020
# Number of Males                        4080
# Number of Children                     8670
# Cause of Death                            0
# Location of death                         0
# Information Source                       23
# Coordinates                              36
# Migrantion route                       2229
# URL                                    2068
# UNSD Geographical Grouping                1
# Source Quality                           42
# dtype: int64

# %%
# Cambiamos el nombre Unnamed:0 a ID y agregar valores secuenciales ala columna ID
df2.rename(columns={'Unnamed: 0': 'ID'}, inplace=True)
df2['ID'] = range(1,len(df2)+1)
df2 = df2.drop(columns=['Main ID','Incident ID','URL','Incident Date','Coordinates'])

# %%
df2['Migrantion route'].value_counts()
# Out:
# Migrantion route
# US-Mexico border crossing                                2638
# Sahara Desert crossing                                   1933
# Central Mediterranean                                     928
# Western Mediterranean                                     526
# Afghanistan to Iran                                       393
# Eastern Mediterranean                                     307
# Western Africa / Atlantic route to the Canary Islands     171
# Western Balkans                                           162
# English Channel to the UK                                 127
# Syria to Turkey                                           127
# Turkey-Europe land route                                  108
# Horn of Africa to Yemen crossing                           63
# Darien Gap                                                 41
# Iran to Turkey                                             29
# Italy to France                                            27
# Dominican Republic to Puerto Rico                          23
# Belarus-EU border                                          21
# Cuba to US                                                 16
# Haiti to Dominican Republic                                13
# Comoros to Mayotte                                         11
# Venezuela to Caribbean                                     10
# DRC to Uganda                                               3
# Name: count, dtype: int64

# %%
# Aqui se uso interpolación porque son numeros secuenciales, es decir continuos, por lo tanto la interpolación aqui es recomendable

df2['Source Quality'].value_counts()
# Out:
# Source Quality
# 2.0    2949
# 5.0    2280
# 4.0    2045
# 1.0    1381
# 3.0    1209
# Name: count, dtype: int64

# %%
df2['Number Dead']= df2['Number Dead'].interpolate().round()
df2['Source Quality']= df2['Source Quality'].interpolate().round()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9906 entries, 0 to 9905
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ID                                   9906 non-null   int64
#  1   Region                               9906 non-null   object
#  2   Year                                 9906 non-null   int64
#  3   Reported Month                       9906 non-null   object
#  4   Number Dead                          9906 non-null   float64
#  5   Minimum Estimated Number of Missing  1035 non-null   float64
#  6   Total Number of Dead and Missing     9906 non-null   int64
#  7   Number of Survivors                  1479 non-null   float64
#  8   Number of Females                    1886 non-null   float64
#  9   Number of Males                      5826 non-null   float64
#  10  Number of Children                   1236 non-null   float64
#  11  Cause of Death                       9906 non-null   object
#  12  Location of death                    9906 non-null   object
#  13  Information Source                   9883 non-null   object
#  14  Migrantion route                     7677 non-null   object
#  15  UNSD Geographical Grouping           9905 non-null   object
#  16  Source Quality                       9906 non-null   float64
# dtypes: float64(7), int64(3), object(7)
# memory usage: 1.3+ MB

# %%
df2['Migrantion route'].value_counts()
# Out:
# Migrantion route
# US-Mexico border crossing                                2638
# Sahara Desert crossing                                   1933
# Central Mediterranean                                     928
# Western Mediterranean                                     526
# Afghanistan to Iran                                       393
# Eastern Mediterranean                                     307
# Western Africa / Atlantic route to the Canary Islands     171
# Western Balkans                                           162
# English Channel to the UK                                 127
# Syria to Turkey                                           127
# Turkey-Europe land route                                  108
# Horn of Africa to Yemen crossing                           63
# Darien Gap                                                 41
# Iran to Turkey                                             29
# Italy to France                                            27
# Dominican Republic to Puerto Rico                          23
# Belarus-EU border                                          21
# Cuba to US                                                 16
# Haiti to Dominican Republic                                13
# Comoros to Mayotte                                         11
# Venezuela to Caribbean                                     10
# DRC to Uganda                                               3
# Name: count, dtype: int64
